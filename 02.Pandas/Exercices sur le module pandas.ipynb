# %% [markdown]
# # Dataframe

# %%
def get_df():
    ratings_df = pd.read_csv("./resources/ratings.csv")
    movies_df = pd.read_csv("./resources/movies.csv")
    movies_rating = movies_df.merge(right = ratings_df, how = "inner", on = "movieId")
    return movies_rating.join(movies_rating["genres"].str.get_dummies(sep = "|"))

def main():
    df = get_df().drop(["movieId", "title", "genres", "userId", "rating", "timestamp"], axis = 1)
    df.sum().plot(kind = "bar")

main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e991bfd7419a> in <module>()
#       9     df.sum().plot(kind = "bar")
#      10
# ---> 11 main()
#
# <ipython-input-1-e991bfd7419a> in main()
#       6
#       7 def main():
# ----> 8     df = get_df().drop(["movieId", "title", "genres", "userId", "rating", "timestamp"], axis = 1)
#       9     df.sum().plot(kind = "bar")
#      10
#
# <ipython-input-1-e991bfd7419a> in get_df()
#       1 def get_df():
# ----> 2     ratings_df = pd.read_csv("./resources/ratings.csv")
#       3     movies_df = pd.read_csv("./resources/movies.csv")
#       4     movies_rating = movies_df.merge(right = ratings_df, how = "inner", on = "movieId")
#       5     return movies_rating.join(movies_rating["genres"].str.get_dummies(sep = "|"))
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Using this link: https://grouplens.org/datasets/movielens/ , you can find the file **ml-latest-small.zip**. The zip contains various data files. You may load different files depending on the exercise.

# %% [markdown]
# # Question 1

# %% [markdown]
# Based on ratings dataset (using file **ratings.csv**):

# %% [markdown]
# 1.1 How many marks were given?

# %% [markdown]
# 1.2	How many different marks were given?

# %% [markdown]
# 1.3 How many marks of 4 were given?

# %% [markdown]
# 1.4 Among these ratings of 4, what is the most popular movie?

# %% [markdown]
# 1.5	How many ratings where given in 2015?

# %% [markdown]
# # Question 2
# Extract year from title into a new column of movie dataset

# %% [markdown]
# # Question 3
# From movie dataset, after having deleted movies without year (see Q2):

# %% [markdown]
# 3.1 How many Thriller movies ?

# %% [markdown]
# 3.2 How many movies in 2016 ?

# %% [markdown]
# 3.3 How many Thriller movies in 2016 ?
